# %% [markdown]
# # Lab 3: Data Analysis with Copilot — Starter Notebook
# **Hartwell Financial Services — Transaction Risk Alert Analysis**
#
# Use this notebook as your working environment for Stages 3 and 4.
# All prompts and instructions are in `LAB_ACTION_GUIDE.md`.
#
# **Dataset:** `../data/transaction_alerts.csv` — 500 synthetic fraud alert records
# **Reference:** `data/schema.md` — column definitions and valid ranges

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %matplotlib inline
print("Environment ready. Libraries loaded.")

# %%
# Load the dataset
df = pd.read_csv('../data/transaction_alerts.csv')
print(f"Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()

# %%
# Quick schema check
print("Column data types:")
print(df.dtypes)
print("\nNull counts per column:")
print(df.isnull().sum())

# %% [markdown]
# ## Your Analysis Starts Here
#
# Replace the cells below with Copilot-generated analysis.
#
# - Use **Stage 1: Data Profiling Analyst** mode to generate profiling code
# - Use **Stage 3: Exploratory Data Analyst** mode for business insights
# - Use **Stage 4: Visualization Architect** mode for labeled charts
#
# Reference: `LAB_ACTION_GUIDE.md` → Quick Reference Table
# Prompts: `reference/PROMPT_PATTERN.md` → RIFCC-DA Template

# %%
# Stage 1 — Data Profiling
# Use Copilot with the Data Profiling Analyst mode
# RIFCC-DA template: reference/PROMPT_PATTERN.md
# Key prompt: generate pandas profiling code that detects nulls, outliers, and schema violations

# %%
# Stage 3 — Exploratory Analysis
# Use Copilot with the Exploratory Data Analyst mode
# Start with: "What alert types have the highest confirmed fraud rates by region?"
# Remember: plain-English findings first, code second

# %%
# Stage 4 — Visualizations
# Use Copilot with the Visualization Architect mode
# Required charts: risk_score distribution, fraud rate by alert_type,
#   transaction_amount by client_segment, prior_alerts_90d vs fraud rate
# Rules: label all axes, no email_masked/account_masked in charts, no 3D charts, Y-axis starts at 0
